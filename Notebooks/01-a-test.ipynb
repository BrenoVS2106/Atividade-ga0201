# %%
import os

project_root = str(os.getenv("PROJECT_ROOT"))

project_root
# Out:
# 'C:\\Users\\Pichau\\Documents\\GitHub\\template-notebooks'

# %%
print(f"Project root is set to: {project_root}")
# Out:
# Project root is set to: C:\Users\Pichau\Documents\GitHub\template-notebooks
